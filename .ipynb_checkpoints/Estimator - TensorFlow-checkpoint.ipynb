# %% [markdown]
# ### Estimator - Basic Regression Model

# %%
import tensorflow as tf
import numpy as np

# %%
x_train = np.array([1.0,2.0,3.0,4.0])
y_train = np.array([-1.0,-2.0,-3.0,-4.0])


#Testing Inputs and Outputs
x_eval = np.array([5.0, 10.0, 15.0,20.0])
y_eval = np.array([-5.0, -10.0, -15.0,-20.0])

# Prediction Inputs
x_predict = np.array([50.0, 100.0])


# Inputs into our model. For each feature/factor we are inputting, we need another feature column
# Think about these as input nodes
feature_column = tf.feature_column.numeric_column(key='x', shape=[1])
feature_columns = [feature_column]

# Type of estimator we are going to use (in this case Linear Regression)
estimator = tf.estimator.LinearRegressor(feature_columns=feature_columns)

# Input function for training the model using training data
input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_train},
                                             y=y_train,
                                             batch_size=4,
                                             num_epochs=None,
                                             shuffle=True)

# Input function for evaluating the training phase of the model using training data
train_input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_train},
                                             y=y_train,
                                             batch_size=4,
                                             num_epochs=1000,
                                             shuffle=False)

# Input function for testing the model using testing data
eval_input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_eval},
                                             y=y_eval,
                                             batch_size=4,
                                             num_epochs=1000,
                                             shuffle=False)

# Input function for predicting using some values
predict_input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_predict},
                                             
                                             num_epochs=1,
                                             shuffle=False)

# Run the training phase with 1000 epochs and the training fucntion
estimator.train(input_fn=input_fn, steps=1000)
# Evaluate the training phase
print(estimator.evaluate(input_fn=train_input_fn))

# Evaluate the testing phase (final Pperformance)
print(estimator.evaluate(input_fn=eval_input_fn))

# Predict using some inputs and our trained model
print(list(estimator.predict(input_fn=predict_input_fn)))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Sunny\\AppData\\Local\\Temp\\tmpnmqrwnst', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002C1B8355DA0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt.
# INFO:tensorflow:loss = 35.0, step = 1
# INFO:tensorflow:global_step/sec: 737.97
# INFO:tensorflow:loss = 0.1425547, step = 101 (0.136 sec)
# INFO:tensorflow:global_step/sec: 1267.38
# INFO:tensorflow:loss = 0.049711898, step = 201 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1336.9
# INFO:tensorflow:loss = 0.023892932, step = 301 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1237.82
# INFO:tensorflow:loss = 0.0062558735, step = 401 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1253.4
# INFO:tensorflow:loss = 0.0006195794, step = 501 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1319.23
# INFO:tensorflow:loss = 0.000789615, step = 601 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1354.76
# INFO:tensorflow:loss = 0.00011749446, step = 701 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1319.58
# INFO:tensorflow:loss = 7.679204e-05, step = 801 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1269.21
# INFO:tensorflow:loss = 4.71608e-05, step = 901 (0.079 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.5974025e-05.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T23:25:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-19-23:25:49
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 2.569304e-06, global_step = 1000, label/mean = -2.5, loss = 1.0277216e-05, prediction/mean = -2.5002437
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt-1000
# {'average_loss': 2.569304e-06, 'label/mean': -2.5, 'loss': 1.0277216e-05, 'prediction/mean': -2.5002437, 'global_step': 1000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T23:25:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-19-23:25:51
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 0.000257194, global_step = 1000, label/mean = -12.5, loss = 0.001028776, prediction/mean = -12.486087
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt-1000
# {'average_loss': 0.000257194, 'label/mean': -12.5, 'loss': 0.001028776, 'prediction/mean': -12.486087, 'global_step': 1000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Sunny\AppData\Local\Temp\tmpnmqrwnst\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'predictions': array([-49.932888], dtype=float32)}, {'predictions': array([-99.862], dtype=float32)}]

# %% [markdown]
# ### Using Custom Estimator Function
# To replace the above Regressor Model
# ```
# estimator = tf.estimator.LinearRegressor(feature_columns=feature_columns)
# ```
# using our custom Estimator i.e. `model_fn`

# %%
import tensorflow as tf
import numpy as np

x_train = np.array([1.0,2.0,3.0,4.0])
y_train = np.array([-1.0,-2.0,-3.0,-4.0])


#Testing Inputs and Outputs
x_eval = np.array([5.0, 10.0, 15.0,20.0])
y_eval = np.array([-5.0, -10.0, -15.0,-20.0])

# Prediction Inputs
x_predict = np.array([50.0, 100.0])

# %%
# y = Wx+b
def model_fn(features, labels, mode):
    #if mode == 'infer':
        #labels = np.array([0,0])
    W = tf.get_variable(name='W', shape=[1], dtype=tf.float64)
    b = tf.get_variable(name='b', shape=[1], dtype=tf.float64)
    y = W * features['x'] + b
    
    loss = tf.reduce_sum(input_tensor=tf.square(x=(y-labels)))
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
    global_step = tf.train.get_global_step()
    
    train_step = tf.group(optimizer.minimize(loss=loss),tf.assign_add(global_step, 1))
    return tf.estimator.EstimatorSpec(
        mode = mode,
        predictions = y,
        loss = loss,
        train_op = train_step
    )

# %%
# Inputs into our model. For each feature/factor we are inputting, we need another feature column
# Think about these as input nodes
feature_column = tf.feature_column.numeric_column(key='x', shape=[1])
feature_columns = [feature_column]

# Type of estimator we are going to use (in this case Linear Regression)
estimator = tf.estimator.Estimator(model_fn=model_fn)

# Input function for training the model using training data
input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_train},
                                             y=y_train,
                                             batch_size=4,
                                             num_epochs=None,
                                             shuffle=True)

# Input function for evaluating the training phase of the model using training data
train_input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_train},
                                             y=y_train,
                                             batch_size=4,
                                             num_epochs=1000,
                                             shuffle=False)

# Input function for testing the model using testing data
eval_input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_eval},
                                             y=y_eval,
                                             batch_size=4,
                                             num_epochs=1000,
                                             shuffle=False)

# Input function for predicting using some values
predict_input_fn = tf.estimator.inputs.numpy_input_fn(x={'x': x_predict},
                                             
                                             num_epochs=1,
                                             shuffle=False)

# Run the training phase with 1000 epochs and the training fucntion
estimator.train(input_fn=input_fn, steps=1000)
# Evaluate the training phase
print(estimator.evaluate(input_fn=train_input_fn))

# Evaluate the testing phase (final Pperformance)
print(estimator.evaluate(input_fn=eval_input_fn))

# Predict using some inputs and our trained model
#print(list(estimator.predict(input_fn=predict_input_fn)))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Sunny\\AppData\\Local\\Temp\\tmpjislcrcf', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002C1B86BE588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf\model.ckpt.
# INFO:tensorflow:loss = 5.567790354899042, step = 1
# INFO:tensorflow:global_step/sec: 771.568
# INFO:tensorflow:loss = 0.0011381645057150903, step = 101 (0.131 sec)
# INFO:tensorflow:global_step/sec: 560.147
# INFO:tensorflow:loss = 4.268483023157104e-05, step = 201 (0.178 sec)
# INFO:tensorflow:global_step/sec: 1055.21
# INFO:tensorflow:loss = 1.1187558584852794e-05, step = 301 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1126.6
# INFO:tensorflow:loss = 1.3033317649095875e-06, step = 401 (0.090 sec)
# INFO:tensorflow:global_step/sec: 1033.69
# INFO:tensorflow:loss = 1.088160155083382e-07, step = 501 (0.098 sec)
# INFO:tensorflow:global_step/sec: 835.552
# INFO:tensorflow:loss = 5.710417017470956e-09, step = 601 (0.123 sec)
# INFO:tensorflow:global_step/sec: 783.3
# INFO:tensorflow:loss = 1.0251256898934041e-09, step = 701 (0.124 sec)
# INFO:tensorflow:global_step/sec: 1033.77
# INFO:tensorflow:loss = 3.752929300598641e-11, step = 801 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1033.66
# INFO:tensorflow:loss = 1.9015087842071686e-12, step = 901 (0.097 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.139596347228894e-13.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T23:40:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-19-23:40:35
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 4.4733076e-13
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf\model.ckpt-1000
# {'loss': 4.4733076e-13, 'global_step': 1000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T23:40:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-19-23:40:36
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 2.9108813e-11
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Sunny\AppData\Local\Temp\tmpjislcrcf\model.ckpt-1000
# {'loss': 2.9108813e-11, 'global_step': 1000}
